# %%
'''
Description:

This project takes a dataset that provides details about cancer cells.  The basis is to create a logistic regression
that is able to classify whether or not a cell is malignant or benign based on the data provided.  Predictions are included,
along with a calculation of the precision, recall, and conufsion matrix derived from the predictions.

The dataset was taken from the UCI Machine Learning Repository.
'''
import pandas as pd

def load_data():
    return pd.read_csv('wdbc.csv', header=0)

# %%
# Print out some data points
data = load_data()
data.head()
# Out:
#          ID Diagnosis  radius1  texture1  perimeter1   area1  smoothness1  \
# 0    842302         M    17.99     10.38      122.80  1001.0      0.11840
# 1    842517         M    20.57     17.77      132.90  1326.0      0.08474
# 2  84300903         M    19.69     21.25      130.00  1203.0      0.10960
# 3  84348301         M    11.42     20.38       77.58   386.1      0.14250
# 4  84358402         M    20.29     14.34      135.10  1297.0      0.10030
#
#    compactness1  concavity1  concave_points1  ...  radius3  texture3  \
# 0       0.27760      0.3001          0.14710  ...    25.38     17.33
# 1       0.07864      0.0869          0.07017  ...    24.99     23.41
# 2       0.15990      0.1974          0.12790  ...    23.57     25.53
# 3       0.28390      0.2414          0.10520  ...    14.91     26.50
# 4       0.13280      0.1980          0.10430  ...    22.54     16.67
#
#    perimeter3   area3  smoothness3  compactness3  concavity3  concave_points3  \
# ...

# %%
# Visualizing the dataset
# %matplotlib inline
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#Data preparation
#Dropping unused column
if 'ID' in data.columns:
    data.drop('ID', axis=1, inplace=True)

#Mapping diagnosis to be an integer (0 for benign, 1 for malignant)
data['Diagnosis'] = data['Diagnosis'].astype(str)
data['Diagnosis'] = data['Diagnosis'].str.strip()
# data.head()

#Map the diagnosis values to integers
diagnosis_mapping = {
    'B': 0,
    'M': 1
}
data['Diagnosis'] = data['Diagnosis'].map(diagnosis_mapping)
data.head()
# Out:
#    Diagnosis  radius1  texture1  perimeter1   area1  smoothness1  \
# 0          1    17.99     10.38      122.80  1001.0      0.11840
# 1          1    20.57     17.77      132.90  1326.0      0.08474
# 2          1    19.69     21.25      130.00  1203.0      0.10960
# 3          1    11.42     20.38       77.58   386.1      0.14250
# 4          1    20.29     14.34      135.10  1297.0      0.10030
#
#    compactness1  concavity1  concave_points1  symmetry1  ...  radius3  \
# 0       0.27760      0.3001          0.14710     0.2419  ...    25.38
# 1       0.07864      0.0869          0.07017     0.1812  ...    24.99
# 2       0.15990      0.1974          0.12790     0.2069  ...    23.57
# 3       0.28390      0.2414          0.10520     0.2597  ...    14.91
# 4       0.13280      0.1980          0.10430     0.1809  ...    22.54
#
#    texture3  perimeter3   area3  smoothness3  compactness3  concavity3  \
# 0     17.33      184.60  2019.0       0.1622        0.6656      0.7119
# ...

# %%
#Removing Diagnosis Column so it is not scaled
from sklearn.preprocessing import StandardScaler

diagnosis = data['Diagnosis']
features = data.drop(columns=['Diagnosis'])

#Scaling features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)
features_df = pd.DataFrame(features_scaled, columns=features.columns)
features_df['Diagnosis'] = diagnosis

features_df.head()
# Out:
#     radius1  texture1  perimeter1     area1  smoothness1  compactness1  \
# 0  1.097064 -2.073335    1.269934  0.984375     1.568466      3.283515
# 1  1.829821 -0.353632    1.685955  1.908708    -0.826962     -0.487072
# 2  1.579888  0.456187    1.566503  1.558884     0.942210      1.052926
# 3 -0.768909  0.253732   -0.592687 -0.764464     3.283553      3.402909
# 4  1.750297 -1.151816    1.776573  1.826229     0.280372      0.539340
#
#    concavity1  concave_points1  symmetry1  fractal_dimension1  ...  texture3  \
# 0    2.652874         2.532475   2.217515            2.255747  ... -1.359293
# 1   -0.023846         0.548144   0.001392           -0.868652  ... -0.369203
# 2    1.363478         2.037231   0.939685           -0.398008  ... -0.023974
# 3    1.915897         1.451707   2.867383            4.910919  ...  0.133984
# 4    1.371011         1.428493  -0.009560           -0.562450  ... -1.466770
#
#    perimeter3     area3  smoothness3  compactness3  concavity3  \
# ...

# %%
#This cell prepares the data for training
data_train = features_df.drop(columns=['Diagnosis'])
x_train_diagnosis = features_df['Diagnosis']
features = features_df.columns.tolist()

some_cell = data_train.iloc[0]
some_cell_df = some_cell.to_frame().T
some_cell_df
# Out:
#     radius1  texture1  perimeter1     area1  smoothness1  compactness1  \
# 0  1.097064 -2.073335    1.269934  0.984375     1.568466      3.283515
#
#    concavity1  concave_points1  symmetry1  fractal_dimension1  ...  radius3  \
# 0    2.652874         2.532475   2.217515            2.255747  ...  1.88669
#
#    texture3  perimeter3     area3  smoothness3  compactness3  concavity3  \
# 0 -1.359293    2.303601  2.001237     1.307686      2.616665    2.109526
#
#    concave_points3  symmetry3  fractal_dimension3
# 0         2.296076   2.750622            1.937015
#
# [1 rows x 30 columns]

# %%
#This cell splits the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_train, x_train_diagnosis, test_size=0.2, random_state=42)

# %%
#This cell trains the regression
from sklearn.linear_model import LogisticRegression

logReg = LogisticRegression()
logReg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#This cell tests the prediction
logReg.predict(some_cell_df)
# Out:
# array([1], dtype=int64)

# %%
#This cell handles creation of the confusion matrix
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix

y_train_pred = cross_val_predict(logReg, X_train, y_train, cv=3)
confusion_matrix(y_train, y_train_pred)
# Out:
# array([[283,   3],
#        [ 12, 157]], dtype=int64)

# %%
#This cell calculates precision
from sklearn.metrics import precision_score, recall_score
precision_score(y_train, y_train_pred)
# Out:
# 0.98125

# %%
#This cell calculates recall
recall_score(y_train, y_train_pred)
# Out:
# 0.9289940828402367
